# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Cargar el CSV
df = pd.read_csv('drones_dataset.csv')  # Cambia 'drones.csv' por el nombre real de tu archivo

# Mostrar primeras filas del DataFrame
print("Primeras filas del archivo CSV:")
print(df.head())

# Mostrar resumen estadístico
print("\nResumen estadístico:")
print(df.describe(include='all'))

# Visualizar la distribución de cada columna
for column in df.columns:
    plt.figure(figsize=(8, 4))
    if df[column].dtype in ['int64', 'float64']:
        sns.histplot(df[column], kde=True, bins=20)
        plt.title(f'Distribución de {column}')
    else:
        sns.countplot(data=df, x=column)
        plt.title(f'Frecuencia de valores en {column}')
        plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()
# Out:
# Primeras filas del archivo CSV:
#                       Drone ID  Flight Radius  Flight height  \
# 0  PowerVision Hydreigon 5000w       7.124924     656.988029
# 1       Parrot Clawitzer 5000M       6.836155     361.353972
# 2          3DR Skarmory 10000U       9.466209     718.104239
# 3  AeroVironment Frosmoth 100M       9.132313     631.998676
# 4      Walkera Volcarona 5000M       0.512549     967.836217
#
#    Thermal/Night Camera  Max wind resistance  Budgets options Camera Quality  \
# 0                     1             4.328739      1052.527631           480p
# 1                     0             9.169118      5910.172328           720p
# 2                     0             9.310168     11051.789618           480p
# 3                     0             7.609319      2210.592466             4K
# 4                     1             6.687345      8592.812889             4K
#
#    ISO range  Battery Life  Payload Capacity  ...  Transmission bandwidth  \
# 0        800    344.868756         21.070658  ...                0.000000
# 1      12800    113.738677         21.256675  ...               32.972932
# 2        400    311.122059         28.802180  ...                0.000000
# 3        800    456.598044         26.313470  ...                0.000000
# 4      25600     74.962066         14.094984  ...                0.000000
#
#    Data storage ability  Air/Water quality sensor availability  Noise level  \
# 0                    32                                      0    44.779260
# 1                    64                                      0    53.116287
# 2                     8                                      1    46.799997
# 3                  1024                                      0    69.459614
# 4                    16                                      0    49.453297
#
#    Operating Temperature  Class Identification Label  Charging Time  \
# 0               7.103664                          C3      60.099387
# 1              18.910171                          C0     100.127844
# 2             -19.009934                          C0     236.220294
# 3              39.335290                          C0     156.834118
# 4              44.534390                          C2     160.378839
#
#   Automatic Landing/Takeoff  GPS Supported Systems  Automated Path Finding
# 0                         1             GPS+BeiDou                       1
# 1                         1                    GPS                       1
# 2                         0            GPS+Galileo                       0
# 3                         0                    GPS                       0
# 4                         1                    GPS                       0
#
# [5 rows x 22 columns]
#
# Resumen estadístico:
#                            Drone ID  Flight Radius  Flight height  \
# count                            56      56.000000      56.000000
# unique                           56            NaN            NaN
# top     PowerVision Hydreigon 5000w            NaN            NaN
# freq                              1            NaN            NaN
# mean                            NaN       6.033974     705.473343
# std                             NaN       3.267837    1061.566777
# min                             NaN       0.512549      10.895514
# 25%                             NaN       3.758578     343.852493
# 50%                             NaN       5.754006     503.439193
# 75%                             NaN       8.265726     734.164840
# max                             NaN      15.000000    6000.000000
#
#         Thermal/Night Camera  Max wind resistance  Budgets options  \
# count              56.000000            56.000000        56.000000
# unique                   NaN                  NaN              NaN
# top                      NaN                  NaN              NaN
# freq                     NaN                  NaN              NaN
# mean                0.482143             8.658585      7823.743355
# std                 0.504203             3.550905      6712.071245
# min                 0.000000             2.382941       305.591908
# 25%                 0.000000             6.264607      3058.990653
# 50%                 0.000000             8.518742      7172.033256
# 75%                 1.000000            11.683192     11138.775328
# max                 1.000000            15.000000     45000.000000
#
#        Camera Quality     ISO range  Battery Life  Payload Capacity  ...  \
# count              56     56.000000     56.000000         56.000000  ...
# unique              5           NaN           NaN               NaN  ...
# top              720p           NaN           NaN               NaN  ...
# freq               18           NaN           NaN               NaN  ...
# mean              NaN   7146.428571    280.550685         14.767496  ...
# std               NaN   9241.939275    173.577922          9.792377  ...
# min               NaN    100.000000     23.000000          0.100000  ...
# 25%               NaN    400.000000    105.291769          5.930938  ...
# 50%               NaN   3200.000000    305.693964         13.972819  ...
# 75%               NaN  12800.000000    432.529292         22.925057  ...
# max               NaN  25600.000000    579.872924         29.876246  ...
#
#         Transmission bandwidth  Data storage ability  \
# count                56.000000             56.000000
# unique                     NaN                   NaN
# top                        NaN                   NaN
# freq                       NaN                   NaN
# mean                 19.133450            282.714286
# std                  25.813575            349.462846
# min                   0.000000              8.000000
# 25%                   0.000000             32.000000
# 50%                   2.500000            128.000000
# 75%                  33.933969            512.000000
# max                  94.471842           1024.000000
#
#         Air/Water quality sensor availability  Noise level  \
# count                               56.000000    56.000000
# unique                                    NaN          NaN
# top                                       NaN          NaN
# freq                                      NaN          NaN
# mean                                 0.446429    59.875567
# std                                  0.501621    16.492034
# min                                  0.000000    33.154820
# 25%                                  0.000000    45.679333
# 50%                                  0.000000    56.926270
# 75%                                  1.000000    75.279738
# max                                  1.000000    89.276166
#
#         Operating Temperature  Class Identification Label  Charging Time  \
# count               56.000000                          56      56.000000
# unique                    NaN                           5            NaN
# top                       NaN                          C0            NaN
# freq                      NaN                          13            NaN
# mean                17.682040                         NaN     133.078374
# std                 20.679629                         NaN      62.186677
# min                -19.009934                         NaN      33.375917
# 25%                 -1.239204                         NaN      78.291627
# 50%                 16.882199                         NaN     120.000000
# 75%                 35.749228                         NaN     190.052341
# max                 49.316730                         NaN     236.220294
#
#        Automatic Landing/Takeoff  GPS Supported Systems  \
# count                  56.000000                     56
# unique                       NaN                      5
# top                          NaN                    GPS
# freq                         NaN                     16
# mean                    0.517857                    NaN
# std                     0.504203                    NaN
# min                     0.000000                    NaN
# 25%                     0.000000                    NaN
# 50%                     1.000000                    NaN
# 75%                     1.000000                    NaN
# max                     1.000000                    NaN
#
#         Automated Path Finding
# count                56.000000
# unique                     NaN
# top                        NaN
# freq                       NaN
# mean                  0.625000
# std                   0.488504
# min                   0.000000
# 25%                   0.000000
# 50%                   1.000000
# 75%                   1.000000
# max                   1.000000
#
# [11 rows x 22 columns]
